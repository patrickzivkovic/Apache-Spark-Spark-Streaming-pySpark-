# %%
# %run spark.py
# Out:
# Enter searchword: racism, police brutality
# Search for: racism, police brutality
# Wait 60 seconds for data to stream properly...
# ...successfull
# Gather Data for hashtag count...
# ...successful
# Gather data for Sentiment Analysis...
# ...successful
# analyse text for sentiment...
# For the text:  Even the statement, “Let’s invite more Black people to the table,” implies ownership of the table and control of who is invited.
# The text polarity is: 0.17
# The text subjectivity is: 0.47
# *****************************************************
# For the text:  Racism is about power.
# The text polarity is: 0.00
# The text subjectivity is: 0.00
# *****************************************************
# For the text:  A South Australian police officer was one of the many people involved in abusing over the past few days. This is a deep, widespread problem.
# The text polarity is: 0.01
# The text subjectivity is: 0.25
# *****************************************************
# ...
